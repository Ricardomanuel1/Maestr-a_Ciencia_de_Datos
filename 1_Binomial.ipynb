# %% [markdown]
# <a href="https://colab.research.google.com/github/Ricardomanuel1/Maestria_Ciencia_de_Datos/blob/main/1_Binomial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Stochastic Simulation: Binomial Distribution

# %% [markdown]
# Simulemos el lanzamiento de $n$ monedas y la probabilidad de obtener $k$ caras. Osea, tenemos $k$ éxitos en $n$ realizaciones de un experimento.

# %%
from random import seed
from matplotlib import pyplot as plt
import numpy as np
from scipy.stats import binom

import math

seed(100) # Semilla del generador de números aleatorios

n = 100 # Número de lanzamientos
p = 0.3 # Probabilidad de obtener cara.
Pk = np.zeros(n)#crea una lista de cien ceros
vk = np.arange(0,n)#crea una lista de números de o hasta 99
ns = 10000 # Número de simulaciones

for j in range(0,ns):#desde cero hasta 10000 simulaciones
    S = 0 # Número de éxitos
    for i in range(0,n):#n es el numero de lanzamientos 100
        r = np.random.uniform() #variable uniforme entre cero y uno
        if(r <= p): # Si r es menor a p=0.3 éxito y si es mayor sera contado como fracaso
            S = S + 1
    Pk[S] = Pk[S] + 1
Pk=Pk/sum(Pk) # Normaliza la distribución
plt.figure(figsize=(10,6))
plt.xlim(0.8*np.min(vk[Pk>0]),1.2*np.max(vk[Pk>0]))
plt.bar(vk, Pk, label='Simulación')

# curva teórica
Pkt = np.zeros(n+1) # valores teóricos
vkt = np.arange(0,n+1)
for k in range(0,n+1):
    Pkt[k] = (math.factorial(n)/(math.factorial(n-k)*math.factorial(k)))*(p**k)*(1-p)**(n-k)
plt.plot(vkt, Pkt, 'r--', label='Prob. Teórica')

plt.xlabel('k', fontsize = 15)
plt.ylabel('P(k)',fontsize = 15)
plt.legend()
plt.show(True)

# %%
vk1 = np.arange(0,5)
vk1
# Out:
# array([0, 1, 2, 3, 4])

# %%
for j in range(0,5):
  print(j)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
P1 = np.zeros(3)
P1
# Out:
# array([0., 0., 0.])

# %%
r = np.random.uniform()
r
# Out:
# 0.6867495160322166

# %%
for i in range(0,5):#n es el numero de lanzamientos 100
  r = np.random.uniform()
  print(r)
# Out:
# 0.5713495544588872
# 0.4904223471236179
# 0.8818306898215651
# 0.9885326020641506
# 0.7191378297421991

# %%
Pk1 = np.zeros(4)
Pk1
# Out:
# array([0., 0., 0., 0.])

# %%
n = 4 # Número de lanzamientos
p = 0.3 # Probabilidad de obtener cara.
Pk1 = np.zeros(n)#crea una lista de 5 ceros
vk1 = np.arange(0,n)#crea un arreglo de números de o hasta 5
ns = 1 # Número de simulaciones

for j in range(0,ns):#desde cero hasta 3 simulaciones
    S = 0 # Número de éxitos
    for i in range(0,n):#n es el numero de lanzamientos 5
      r = np.random.uniform() #variable uniforme entre cero y uno
      if(r <= p): # Si r es menor a p=0.3 éxito y si es mayor sera contado como fracaso
        #print(r)
        S = S + 1
    Pk1[S] = Pk1[S] + 1
print(Pk1)
Pk1=Pk1/sum(Pk1) # Normaliza la distribución
# Out:
# [0. 1. 0. 0.]
