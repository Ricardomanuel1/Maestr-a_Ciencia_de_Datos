# %% [markdown]
# <a href="https://colab.research.google.com/github/Ricardomanuel1/Maestria_Ciencia_de_Datos/blob/main/III.%20Matematica_Ciencia_Datos/5_Variables_Aleat%C3%B3rias.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Ejemplo 1:
# Una urna contiene cinco bolas numeradas 1, 2, 2, 8 y 8. Si
# una persona selecciona tres bolas al azar y definimos la variable aleatoria $X$ como la suma obtenida por las tres bolas.

# %% [markdown]
# ## (a) Calculando la Función de Probabilidad - f(x)=Prob(X=x)

# %%
#1,2,2,8,8
X=['Suma=5','Suma=11','Suma=12','Suma=17','Suma=18']
P=[0.1, 0.4,0.2,0.1,0.2]

# %%
df=pd.DataFrame()
df['x']=X
df['f(x)']=P
df.set_index('x',inplace=True)
df
# Out:
#          f(x)
# x
# Suma=5    0.1
# Suma=11   0.4
# Suma=12   0.2
# Suma=17   0.1
# Suma=18   0.2

# %%
plt.plot(df['f(x)'],marker='*')
plt.ylim(0,1.1)
plt.show()

# %% [markdown]
# ## (b) Calculando la Función de Probabilidad Acumulada - F(x)

# %%
X=['Suma=5','Suma=11','Suma=12','Suma=17','Suma=18']
P=[0.1, 0.4,0.2,0.1,0.2]

# %%
df=pd.DataFrame()
df['x']=X
df['f(x)']=P
df['F(x)']=np.cumsum(df['f(x)'])
df.set_index('x',inplace=True)
df
# Out:
#          f(x)  F(x)
# x
# Suma=5    0.1   0.1
# Suma=11   0.4   0.5
# Suma=12   0.2   0.7
# Suma=17   0.1   0.8
# Suma=18   0.2   1.0

# %%
plt.plot(df['F(x)'],marker='*')
plt.ylim(0,1.1)
plt.show()

# %% [markdown]
# ## (c) Calcular E(X)

# %%
df=pd.DataFrame()
X_ind=['Suma=5','Suma=11','Suma=12','Suma=17','Suma=18']
X=[5,11,12,17,18]
P=[0.1, 0.4,0.2,0.1,0.2]
df['x_ind']=X_ind
df['x']=X
df['f(x)']=P
df['x*f(x)']=df['x']*df['f(x)']
df.set_index('x_ind',inplace=True)
df
# Out:
#           x  f(x)  x*f(x)
# x_ind
# Suma=5    5   0.1     0.5
# Suma=11  11   0.4     4.4
# Suma=12  12   0.2     2.4
# Suma=17  17   0.1     1.7
# Suma=18  18   0.2     3.6

# %%
Valor_Esperado=df['x*f(x)'].sum()
print('El Valor Esperado es', Valor_Esperado)
# Out:
# El Valor Esperado es 12.6

# %% [markdown]
# ## (d) Calculando Varianza y Desviación Estandar usando Formula 1
# $$Var(X)= E([X-E(X)]^2)\quad\text{y}\quad sd(X)=\sqrt{Var(X)}.$$

# %%
df=pd.DataFrame()
X_ind=['Suma=5','Suma=11','Suma=12','Suma=17','Suma=18']
X=[5,11,12,17,18]
P=[0.1, 0.4,0.2,0.1,0.2]
df['x_ind']=X_ind
df['x']=X
df['f(x)']=P
df['x*f(x)']=df['x']*df['f(x)']
Valor_Esperado=df['x*f(x)'].sum()
print('------------------------------------------------------------------------')
print('Tabla de Distribución de Probabilidades')
print('------------------------------------------------------------------------')
df['x-E(X)']=df['x']-Valor_Esperado
df['[x-E(X)]^2']=df['x-E(X)']*df['x-E(X)']
df['[x-E(X)]^2 * f(x)']=df['[x-E(X)]^2']*df['f(x)']
df.set_index('x_ind',inplace=True)
Varianza=df['[x-E(X)]^2 * f(x)'].sum()
print(df)
print('------------------------------------------------------------------------')
print('E(X)=', Valor_Esperado)
print('------------------------------------------------------------------------')
print('Var(X)=',Varianza)
print('------------------------------------------------------------------------')
print('sd(X)',round(np.sqrt(Varianza),2))
print('------------------------------------------------------------------------')
# Out:
# ------------------------------------------------------------------------
# Tabla de Distribución de Probabilidades
# ------------------------------------------------------------------------
#           x  f(x)  x*f(x)  x-E(X)  [x-E(X)]^2  [x-E(X)]^2 * f(x)
# x_ind
# Suma=5    5   0.1     0.5    -7.6       57.76              5.776
# Suma=11  11   0.4     4.4    -1.6        2.56              1.024
# Suma=12  12   0.2     2.4    -0.6        0.36              0.072
# Suma=17  17   0.1     1.7     4.4       19.36              1.936
# Suma=18  18   0.2     3.6     5.4       29.16              5.832
# ------------------------------------------------------------------------
# E(X)= 12.6
# ------------------------------------------------------------------------
# Var(X)= 14.64
# ------------------------------------------------------------------------
# sd(X) 3.83
# ------------------------------------------------------------------------

# %% [markdown]
# ## (e) Calculando Varianza y Desviación Estandar usando Formula 2
# $$Var(X)= E(X^2)-E(X)^2\quad\text{y}\quad sd(X)=\sqrt{Var(X)}.$$

# %%
df=pd.DataFrame()
X_ind=['Suma=5','Suma=11','Suma=12','Suma=17','Suma=18']
X=[5,11,12,17,18]
P=[0.1, 0.4,0.2,0.1,0.2]
df['x_ind']=X_ind
df['x']=X
df['f(x)']=P
df['x*f(x)']=df['x']*df['f(x)']
Valor_Esperado=df['x*f(x)'].sum()
df['x^2']=df['x']*df['x']
df['x^2*f(x)']=df['x^2']*df['f(x)']
df.set_index('x_ind',inplace=True)
Valor_Esperado=df['x*f(x)'].sum()
Varianza=df['x^2*f(x)'].sum()-Valor_Esperado**2

# %%
print('------------------------------------------------------------------------')
print('Tabla de Distribución de Probabilidades')
print('------------------------------------------------------------------------')
print(df)
print('------------------------------------------------------------------------')
print('E(X)=', Valor_Esperado)
print('------------------------------------------------------------------------')
print('Var(X)=',round(Varianza,2))
print('------------------------------------------------------------------------')
print('sd(X)',round(np.sqrt(Varianza),2))
print('------------------------------------------------------------------------')
# Out:
# ------------------------------------------------------------------------
# Tabla de Distribución de Probabilidades
# ------------------------------------------------------------------------
#           x  f(x)  x*f(x)  x^2  x^2*f(x)
# x_ind
# Suma=5    5   0.1     0.5   25       2.5
# Suma=11  11   0.4     4.4  121      48.4
# Suma=12  12   0.2     2.4  144      28.8
# Suma=17  17   0.1     1.7  289      28.9
# Suma=18  18   0.2     3.6  324      64.8
# ------------------------------------------------------------------------
# E(X)= 12.6
# ------------------------------------------------------------------------
# Var(X)= 14.64
# ------------------------------------------------------------------------
# sd(X) 3.83
# ------------------------------------------------------------------------

# %% [markdown]
# # Ejemplo 2:
#
# Una urna contiene 5 bolas azules y 7 grises. Digamos que se eligen 2 al azar, uno tras otro el otro, sin reemplazo. Si definimos la variable aleatória $X$ para definir la cantidad de bolas azules obtenidas.

# %% [markdown]
# ## (a) Calculando la Función de Probabilidad - f(x)

# %%
#Efectuando el arbol de probabilidades
#X=0 GG    ...........(7/12)*(6/11)                 P(x=0)=0.318
#X=1 GA,AG ...........(7/12)*(5/11)+ (5/12)*(7/11)  P(x=1)=0.530
#X=2 AA    ...........(5/11)*(4/11)                 P(x=2)=0.165
X=['GG','GA-AG','AA']
P=[0.318, 0.53,0.165]

# %%
df=pd.DataFrame()
df['x']=X
df['f(x)']=P
df.set_index('x',inplace=True)
df
# Out:
#         f(x)
# x
# GG     0.318
# GA-AG  0.530
# AA     0.165

# %%
plt.plot(df['f(x)'],marker='*')
plt.ylim(0,1.1)
plt.show()

# %% [markdown]
# ## (b) Calculando la Función de Probabilidad Acumulada- F(x)

# %%
df=pd.DataFrame()
df['x']=X
df['f(x)']=P
df['F(x)']=np.cumsum(df['f(x)'])
df.set_index('x',inplace=True)
df
# Out:
#         f(x)   F(x)
# x
# GG     0.318  0.318
# GA-AG  0.530  0.848
# AA     0.165  1.013

# %%
plt.plot(df['F(x)'],marker='*')
plt.ylim(0,1.1)
plt.show()

# %% [markdown]
# ## (c) Calcular E(X)

# %%
df=pd.DataFrame()
X_ind=['GG','GA-AG','AA']
X=[0,1,2]
P=[0.318,0.530,0.165]
df['x_ind']=X_ind
df['x']=X
df['f(x)']=P
df['x*f(x)']=df['x']*df['f(x)']
df.set_index('x_ind',inplace=True)
df
# Out:
#        x   f(x)  x*f(x)
# x_ind
# GG     0  0.318    0.00
# GA-AG  1  0.530    0.53
# AA     2  0.165    0.33

# %%
Valor_Esperado=df['x*f(x)'].sum()
print('El Valor Esperado es', Valor_Esperado)
# Out:
# El Valor Esperado es 0.8600000000000001

# %% [markdown]
# ## (d) Calculando Varianza y Desviación Estandar usando Formula 1
# $$Var(X)= E([X-E(X)]^2)\quad\text{y}\quad sd(X)=\sqrt{Var(X)}.$$

# %%
df=pd.DataFrame()
X_ind=['GG','GA-AG','AA']
X=[0,1,2]
P=[0.318,0.530,0.165]
df['x_ind']=X_ind
df['x']=X
df['f(x)']=P
df['x*f(x)']=df['x']*df['f(x)']
Valor_Esperado=df['x*f(x)'].sum()
print('------------------------------------------------------------------------')
print('Tabla de Distribución de Probabilidades')
print('------------------------------------------------------------------------')
df['x-E(X)']=df['x']-Valor_Esperado
df['[x-E(X)]^2']=df['x-E(X)']*df['x-E(X)']
df['[x-E(X)]^2 * f(x)']=df['[x-E(X)]^2']*df['f(x)']
df.set_index('x_ind',inplace=True)
Varianza=df['[x-E(X)]^2 * f(x)'].sum()
print(df)
print('------------------------------------------------------------------------')
print('E(X)=', Valor_Esperado)
print('------------------------------------------------------------------------')
print('Var(X)=',Varianza)
print('------------------------------------------------------------------------')
print('sd(X)',round(np.sqrt(Varianza),2))
print('------------------------------------------------------------------------')
# Out:
# ------------------------------------------------------------------------
# Tabla de Distribución de Probabilidades
# ------------------------------------------------------------------------
#        x   f(x)  x*f(x)  x-E(X)  [x-E(X)]^2  [x-E(X)]^2 * f(x)
# x_ind
# GG     0  0.318    0.00   -0.86      0.7396           0.235193
# GA-AG  1  0.530    0.53    0.14      0.0196           0.010388
# AA     2  0.165    0.33    1.14      1.2996           0.214434
# ------------------------------------------------------------------------
# E(X)= 0.8600000000000001
# ------------------------------------------------------------------------
# Var(X)= 0.46001480000000006
# ------------------------------------------------------------------------
# sd(X) 0.68
# ------------------------------------------------------------------------

# %% [markdown]
# ## (e) Calculando Varianza y Desviación Estandar usando Formula 2
# $$Var(X)= E(X^2)-E(X)^2\quad\text{y}\quad sd(X)=\sqrt{Var(X)}.$$

# %%
df=pd.DataFrame()
X_ind=['GG','GA-AG','AA']
X=[0,1,2]
P=[0.318,0.530,0.165]
df['x_ind']=X_ind
df['x']=X
df['f(x)']=P
df['x*f(x)']=df['x']*df['f(x)']
Valor_Esperado=df['x*f(x)'].sum()
df['x^2']=df['x']*df['x']
df['x^2*f(x)']=df['x^2']*df['f(x)']
df.set_index('x_ind',inplace=True)
Valor_Esperado=df['x*f(x)'].sum()
Varianza=df['x^2*f(x)'].sum()-Valor_Esperado**2

# %%
print('------------------------------------------------------------------------')
print('Tabla de Distribución de Probabilidades')
print('------------------------------------------------------------------------')
print(df)
print('------------------------------------------------------------------------')
print('E(X)=', Valor_Esperado)
print('------------------------------------------------------------------------')
print('Var(X)=',round(Varianza,2))
print('------------------------------------------------------------------------')
print('sd(X)',round(np.sqrt(Varianza),2))
print('------------------------------------------------------------------------')
# Out:
# ------------------------------------------------------------------------
# Tabla de Distribución de Probabilidades
# ------------------------------------------------------------------------
#        x   f(x)  x*f(x)  x^2  x^2*f(x)
# x_ind
# GG     0  0.318    0.00    0      0.00
# GA-AG  1  0.530    0.53    1      0.53
# AA     2  0.165    0.33    4      0.66
# ------------------------------------------------------------------------
# E(X)= 0.8600000000000001
# ------------------------------------------------------------------------
# Var(X)= 0.45
# ------------------------------------------------------------------------
# sd(X) 0.67
# ------------------------------------------------------------------------
