# %% [markdown]
# <a href="https://colab.research.google.com/github/Ricardomanuel1/Maestria_Ciencia_de_Datos/blob/main/II.%20Introduccion_Ciencia_Datos/6_Regresi%C3%B3nLogistica_Ejercicio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ejercicio Regresión Logística
#
# El conjunto de datos tiene el registro de si un usuario de internet clica en un anuncio de una compañía. Se quiere construir un modelo para predecir si un usuario clicará un anuncio basado en sus datos.
#
# Características:
#
# * 'Daily Time Spent on Site': tiempo gastado en la página en minutos
# * 'Age': edad del cliente en años
# * 'Area Income': ingreso promedio por área geográfica
# * 'Daily Internet Usage': promedio de consumo internet en minutos por dia
# * 'Ad Topic Line': encabezado del anuncio
# * 'City': Ciudad del cliente
# * 'Male': género
# * 'Country': país del cliente
# * 'Timestamp': tiempo en que se clicó en el anuncio o se cerró la ventana
# * 'Clicked on Ad': 1 ó 0 indicando si clicó en el anuncio (**Variable o clase a predecir**)
#
#
# **Importar las librerias necesarias**

# %% [markdown]
# ## Obtención de los datos
# **Leer el archivo advertising.csv en un DataFrame llamado datos**

# %%
url = "https://raw.githubusercontent.com/eduardool/MaestriaCienciaDatos/main/datasets/advertising.csv"

# %% [markdown]
# **Verificar el head() de datos**

# %%
# Out:
#    Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                     68.95   35     61833.90                256.09
# 1                     80.23   31     68441.85                193.77
# 2                     69.47   26     59785.94                236.50
# 3                     74.15   29     54806.18                245.89
# 4                     68.37   35     73889.99                225.58
#
#                            Ad Topic Line            City  Male     Country  \
# 0     Cloned 5thgeneration orchestration     Wrightburgh     0     Tunisia
# 1     Monitored national standardization       West Jodi     1       Nauru
# 2       Organic bottom-line service-desk        Davidton     0  San Marino
# 3  Triple-buffered reciprocal time-frame  West Terrifurt     1       Italy
# 4          Robust logistical utilization    South Manuel     0     Iceland
#
#              Timestamp  Clicked on Ad
# 0  2016-03-27 00:53:11              0
# ...

# %% [markdown]
# **Imprimir  info y describe()**

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Daily Time Spent on Site  1000 non-null   float64
#  1   Age                       1000 non-null   int64
#  2   Area Income               1000 non-null   float64
#  3   Daily Internet Usage      1000 non-null   float64
#  4   Ad Topic Line             1000 non-null   object
#  5   City                      1000 non-null   object
#  6   Male                      1000 non-null   int64
#  7   Country                   1000 non-null   object
#  8   Timestamp                 1000 non-null   object
#  9   Clicked on Ad             1000 non-null   int64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 78.2+ KB

# %%
# Out:
#        Daily Time Spent on Site          Age   Area Income  \
# count               1000.000000  1000.000000   1000.000000
# mean                  65.000200    36.009000  55000.000080
# std                   15.853615     8.785562  13414.634022
# min                   32.600000    19.000000  13996.500000
# 25%                   51.360000    29.000000  47031.802500
# 50%                   68.215000    35.000000  57012.300000
# 75%                   78.547500    42.000000  65470.635000
# max                   91.430000    61.000000  79484.800000
#
#        Daily Internet Usage         Male  Clicked on Ad
# count           1000.000000  1000.000000     1000.00000
# mean             180.000100     0.481000        0.50000
# std               43.902339     0.499889        0.50025
# min              104.780000     0.000000        0.00000
# 25%              138.830000     0.000000        0.00000
# 50%              183.130000     0.000000        0.50000
# ...

# %% [markdown]
# ## Análisis Exploratorio de Datos
#
#
#
# **Crear un histograma de Age**

# %%
# Out:
# Text(0.5, 0, 'Edad')

# %% [markdown]
# **Crear un jointplot (librería SNS) mostrando Area Income versus Age.**

# %% [markdown]
# **Crear un jointplot mostrando distribuciones KDE (kind='kde') de Daily Time spent on site vs. Age.**

# %% [markdown]
# **Crear un jointplot de 'Daily Time Spent on Site' vs. 'Daily Internet Usage'**

# %% [markdown]
# ## Regresión Logística

# %% [markdown]
# **Separa datos en entrenamiento y prueba (random_state=42, test_size = 0.33)**

# %% [markdown]
# **Entrenar un modelo de Regresión Logística con los datos de entrenamiento**

# %%
f

# %%
# Out:
# LogisticRegression()

# %% [markdown]
# ## Predicciones y Evaluaciones
#
# **Predecir valores del conjunto de prueba**

# %% [markdown]
# **Crear un reporte de clasificación del modelo**

# %%
print(classification_report(y_prueba,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.96      0.91       162
#            1       0.96      0.85      0.90       168
#
#     accuracy                           0.91       330
#    macro avg       0.91      0.91      0.91       330
# weighted avg       0.91      0.91      0.91       330
