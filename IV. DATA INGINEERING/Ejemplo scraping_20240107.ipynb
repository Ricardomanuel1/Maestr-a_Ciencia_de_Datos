# %% [markdown]
# <a href="https://colab.research.google.com/github/Ricardomanuel1/Maestria_Ciencia_de_Datos/blob/main/IV.%20DATA%20INGINEERING/Ejemplo%20scraping_20240107.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
ls
# Out:
# sample_data/

# %%
pwd
# Out:
# '/content'

# %%
# !pip install wget
import wget
URL = "https://instagram.com/favicon.ico"
response = wget.download(URL, "instagram.ico")
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9655 sha256=8bfe2aced86b93b61cc17714d21673c3915a0b7ee9f31fbba959892f5c3785ec
#   Stored in directory: /root/.cache/pip/wheels/8b/f1/7f/5c94f0a7a505ca1c81cd1d9208ae2064675d97582078e6c769
# Successfully built wget
# ...

# %%
ls
# Out:
# instagram.ico  sample_data/

# %%
##Congreso TRANSPARENCIA
# https://www.congreso.gob.pe/Portal_Transparencia

path = 'https://www.transparencia.gob.pe/personal/pte_transparencia_personal_genera.aspx?id_entidad=16&in_anno_consulta=2022&ch_mes_consulta=07&ch_tipo_regimen=0&vc_dni_funcionario=&vc_nombre_funcionario=&ch_tipo_descarga=1'
print(path)
path
# Out:
# https://www.transparencia.gob.pe/personal/pte_transparencia_personal_genera.aspx?id_entidad=16&in_anno_consulta=2022&ch_mes_consulta=07&ch_tipo_regimen=0&vc_dni_funcionario=&vc_nombre_funcionario=&ch_tipo_descarga=1
# 'https://www.transparencia.gob.pe/personal/pte_transparencia_personal_genera.aspx?id_entidad=16&in_anno_consulta=2022&ch_mes_consulta=07&ch_tipo_regimen=0&vc_dni_funcionario=&vc_nombre_funcionario=&ch_tipo_descarga=1'

# %%
#### MISNA TRANSPARENCIA
#https://transparencia.gob.pe/enlaces/pte_transparencia_enlaces.aspx?id_entidad=143#.Yzb7_HbMJPY
path = 'https://transparencia.gob.pe/personal/pte_transparencia_personal_genera.aspx?id_entidad=143&in_anno_consulta=2022&ch_mes_consulta=07&ch_tipo_regimen=0&vc_dni_funcionario=&vc_nombre_funcionario=&ch_tipo_descarga=1'
print(path)
# Out:
# https://transparencia.gob.pe/personal/pte_transparencia_personal_genera.aspx?id_entidad=143&in_anno_consulta=2022&ch_mes_consulta=07&ch_tipo_regimen=0&vc_dni_funcionario=&vc_nombre_funcionario=&ch_tipo_descarga=1

# %%
### ONP
#https://www.transparencia.gob.pe/personal/pte_transparencia_personal.aspx?id_entidad=82&id_tema=32&ver=

path =  'https://www.transparencia.gob.pe/personal/pte_transparencia_personal_genera.aspx?id_entidad=82&in_anno_consulta=2023&ch_mes_consulta=07&ch_tipo_regimen=0&vc_dni_funcionario=&vc_nombre_funcionario=&ch_tipo_descarga=1'
print(path)
# Out:
# https://www.transparencia.gob.pe/personal/pte_transparencia_personal_genera.aspx?id_entidad=82&in_anno_consulta=2023&ch_mes_consulta=07&ch_tipo_regimen=0&vc_dni_funcionario=&vc_nombre_funcionario=&ch_tipo_descarga=1

# %%
# %%time
response = wget.download(path )
# Out:
# CPU times: user 31 ms, sys: 6.72 ms, total: 37.7 ms
# Wall time: 2.65 s

# %%
ls
# Out:
# DownloadMobileNoExcel.xls  instagram.ico  pte_transparencia_personal_genera.aspx  sample_data/

# %%
mes = '202307'
# !cp DownloadMobileNoExcel.xls  transparencia_ONP_{mes}.xls

# %%
ls
# Out:
# DownloadMobileNoExcel.xls  pte_transparencia_personal_genera.aspx  transparencia_ONP_202307.xls
# instagram.ico              sample_data/

# %%
# %%time
anho = '2023' #202205
mes = '05'
codmes = f'{anho}{mes}'
print(codmes)
path0 =  f'https://www.transparencia.gob.pe/personal/pte_transparencia_personal_genera.aspx?id_entidad=82&in_anno_consulta={anho}&ch_mes_consulta={mes}&ch_tipo_regimen=0&vc_dni_funcionario=&vc_nombre_funcionario=&ch_tipo_descarga=1'
print(path0)
response = wget.download(path0, out =   f'transparencia_ONP_{codmes}.xls' )
#!cp DownloadMobileNoExcel.xls  f'transparencia_{codmes}.xls'
# !ls
# Out:
# 202305
# https://www.transparencia.gob.pe/personal/pte_transparencia_personal_genera.aspx?id_entidad=82&in_anno_consulta=2023&ch_mes_consulta=05&ch_tipo_regimen=0&vc_dni_funcionario=&vc_nombre_funcionario=&ch_tipo_descarga=1
# DownloadMobileNoExcel.xls  pte_transparencia_personal_genera.aspx  transparencia_ONP_202305.xls
# instagram.ico		   sample_data				   transparencia_ONP_202307.xls
# CPU times: user 40.4 ms, sys: 12.1 ms, total: 52.5 ms
# Wall time: 3.31 s

# %%
ls *xls -tr -g -h
# Out:
# -rw-r--r-- 1 root 555K Jan  7 13:45 DownloadMobileNoExcel.xls
# -rw-r--r-- 1 root 555K Jan  7 13:45 transparencia_ONP_202307.xls
# -rw-r--r-- 1 root 581K Jan  7 13:46 transparencia_ONP_202305.xls

# %%
import pandas as pd
import numpy as np

df = pd.read_html('transparencia_ONP_202307.xls')[0]
cols = list(df.iloc[0])
df = df.iloc[1:]
df
# Out:
#             0            1     2  3  4          5           6   \
# 1     68216120  20254165035  2023  7  9     MAMANI      QUILLA
# 2     68216121  20254165035  2023  7  9    TORIBIO        CAYO
# 3     68216122  20254165035  2023  7  9  CHAFLOQUE      FABIAN
# 4     68216123  20254165035  2023  7  9   GONZALES   FERNANDEZ
# 5     68216124  20254165035  2023  7  9   ESPINOZA     TIMOTEO
# ...        ...          ...   ... .. ..        ...         ...
# 1643  68217762  20254165035  2023  7  1      VERDE  PUMACHAICO
# 1644  68217763  20254165035  2023  7  1    VERGARA     GUILLEN
# 1645  68217764  20254165035  2023  7  1       VIGO        RUIZ
# 1646  68217765  20254165035  2023  7  1       VIGO     VASQUEZ
# 1647  68217766  20254165035  2023  7  1    VILCHEZ      ARROYO
#
#                     7                             8   \
# 1           EDY WILSON                 CA1-Asistente
# 2       JOSELIN MARGOT                  CA2-Analista
# ...

# %%
# %%time
df = pd.read_html('transparencia_ONP_202307.xls')[0]
cols = list(df.iloc[0])
df = df.iloc[1:]
df.columns = cols
print(cols )
df.head()
# Out:
# ['PK_ID_PERSONAL', 'VC_PERSONAL_RUC_ENTIDAD', 'IN_PERSONAL_ANNO', 'IN_PERSONAL_MES', 'VC_PERSONAL_REGIMEN_LABORAL', 'VC_PERSONAL_PATERNO', 'VC_PERSONAL_MATERNO', 'VC_PERSONAL_NOMBRES', 'VC_PERSONAL_CARGO', 'VC_PERSONAL_DEPENDENCIA', 'MO_PERSONAL_REMUNERACIONES', 'MO_PERSONAL_HONORARIOS', 'MO_PERSONAL_INCENTIVO', 'MO_PERSONAL_GRATIFICACION', 'MO_PERSONAL_OTROS_BENEFICIOS', 'MO_PERSONAL_TOTAL', 'VC_PERSONAL_OBSERVACIONES', 'FEC_REG']
# CPU times: user 471 ms, sys: 6.28 ms, total: 477 ms
# Wall time: 481 ms
#   PK_ID_PERSONAL VC_PERSONAL_RUC_ENTIDAD IN_PERSONAL_ANNO IN_PERSONAL_MES  \
# 1       68216120             20254165035             2023               7
# 2       68216121             20254165035             2023               7
# 3       68216122             20254165035             2023               7
# 4       68216123             20254165035             2023               7
# 5       68216124             20254165035             2023               7
#
# ...

# %%
df[['VC_PERSONAL_PATERNO', 'VC_PERSONAL_MATERNO', 'VC_PERSONAL_NOMBRES']].value_counts()
# Out:
# VC_PERSONAL_PATERNO  VC_PERSONAL_MATERNO  VC_PERSONAL_NOMBRES
# TICONA               CANO                 ARTURO JOSE            4
# HEINSOHN             ABAD                 ELIZABETH YULIANA      4
# MARIÑOS              ALFARO               EDUARDO JOSUE          4
# GONZALES             FERNANDEZ            MARIA ANTONIETA        4
# CRUZADO              MERCADO              GLADIS ISIDORA         4
#                                                                 ..
# MEDINA               QUIROZ               YESSICA CATALINA       1
#                      BERROSPI             OLGA YANELLY           1
# MAYTA                LOPEZ                LISBETH ANAIS          1
# MAURICIO             ORIHUELA             EDITH JENNY            1
# ÑAVINCOPA            CARRILLO             MARILENA VERONICA      1
# Length: 906, dtype: int64

# %%
df[df['VC_PERSONAL_NOMBRES'] == 'ARTURO JOSE']
# Out:
#     PK_ID_PERSONAL VC_PERSONAL_RUC_ENTIDAD IN_PERSONAL_ANNO IN_PERSONAL_MES  \
# 17        68216136             20254165035             2023               7
# 53        68216172             20254165035             2023               7
# 281       68216400             20254165035             2023               7
# 580       68216699             20254165035             2023               7
#
#     VC_PERSONAL_REGIMEN_LABORAL VC_PERSONAL_PATERNO VC_PERSONAL_MATERNO  \
# 17                            9              TICONA                CANO
# 53                            9              TICONA                CANO
# 281                           9              TICONA                CANO
# 580                           9              TICONA                CANO
#
#     VC_PERSONAL_NOMBRES VC_PERSONAL_CARGO    VC_PERSONAL_DEPENDENCIA  \
# 17          ARTURO JOSE     CA1-Asistente  DIRECCIÓN DE PRESTACIONES
# 53          ARTURO JOSE     CA1-Asistente  DIRECCIÓN DE PRESTACIONES
# ...

# %%
df['nombre'] = df.VC_PERSONAL_PATERNO + '_' +  df.VC_PERSONAL_MATERNO +  '_' + df.VC_PERSONAL_NOMBRES
df.head()
# Out:
#   PK_ID_PERSONAL VC_PERSONAL_RUC_ENTIDAD IN_PERSONAL_ANNO IN_PERSONAL_MES  \
# 1       68216120             20254165035             2023               7
# 2       68216121             20254165035             2023               7
# 3       68216122             20254165035             2023               7
# 4       68216123             20254165035             2023               7
# 5       68216124             20254165035             2023               7
#
#   VC_PERSONAL_REGIMEN_LABORAL VC_PERSONAL_PATERNO VC_PERSONAL_MATERNO  \
# 1                           9              MAMANI              QUILLA
# 2                           9             TORIBIO                CAYO
# 3                           9           CHAFLOQUE              FABIAN
# 4                           9            GONZALES           FERNANDEZ
# 5                           9            ESPINOZA             TIMOTEO
#
#   VC_PERSONAL_NOMBRES             VC_PERSONAL_CARGO  \
# ...

# %%
rename = { 'PK_ID_PERSONAL' : 'pk_id_personal',
# 'VC_PERSONAL_RUC_ENTIDAD',
# 'IN_PERSONAL_ANNO',
# 'IN_PERSONAL_MES',
 'VC_PERSONAL_REGIMEN_LABORAL': 'vc_regimen_laboral',
# 'VC_PERSONAL_PATERNO',
# 'VC_PERSONAL_MATERNO',
# 'VC_PERSONAL_NOMBRES',
 'VC_PERSONAL_CARGO' : 'vc_cargo',
 'VC_PERSONAL_DEPENDENCIA': 'vc_dependencia',
 'MO_PERSONAL_REMUNERACIONES' : 'mo_remuneraciones',
 'MO_PERSONAL_HONORARIOS' : 'mo_honorarios',
 'MO_PERSONAL_INCENTIVO' : 'mo_incentivo',
 'MO_PERSONAL_GRATIFICACION': 'mo_gratificacion',
 'MO_PERSONAL_OTROS_BENEFICIOS' : 'mo_otros_beneficios',
 'MO_PERSONAL_TOTAL' : 'mo_total',
 'VC_PERSONAL_OBSERVACIONES' : 'vc_obervaciones', }
# 'FEC_REG']
df = df.rename(columns = rename)
df.head()
# Out:
#   pk_id_personal VC_PERSONAL_RUC_ENTIDAD IN_PERSONAL_ANNO IN_PERSONAL_MES  \
# 1       68216120             20254165035             2023               7
# 2       68216121             20254165035             2023               7
# 3       68216122             20254165035             2023               7
# 4       68216123             20254165035             2023               7
# 5       68216124             20254165035             2023               7
#
#   vc_regimen_laboral VC_PERSONAL_PATERNO VC_PERSONAL_MATERNO  \
# 1                  9              MAMANI              QUILLA
# 2                  9             TORIBIO                CAYO
# 3                  9           CHAFLOQUE              FABIAN
# 4                  9            GONZALES           FERNANDEZ
# 5                  9            ESPINOZA             TIMOTEO
#
#   VC_PERSONAL_NOMBRES                      vc_cargo  \
# 1          EDY WILSON                 CA1-Asistente
# ...

# %%
#df.columns
cols = ['nombre'  , 'vc_regimen_laboral',  'vc_cargo',
       'vc_dependencia', 'mo_remuneraciones', 'mo_honorarios', 'mo_incentivo',
       'mo_gratificacion', 'mo_otros_beneficios', 'mo_total',
       'vc_obervaciones']
df = df[cols].copy()

col_float = [ 'mo_remuneraciones', 'mo_honorarios', 'mo_incentivo',
       'mo_gratificacion', 'mo_otros_beneficios', 'mo_total']
for c in col_float:
    df[c] =  pd.to_numeric(df[c] ,  errors = 'coerce' )
df['codmes'] = anho+mes
df.head()
# Out:
#                                nombre vc_regimen_laboral  \
# 1            MAMANI_QUILLA_EDY WILSON                  9
# 2         TORIBIO_CAYO_JOSELIN MARGOT                  9
# 3     CHAFLOQUE_FABIAN_SEGUNDO ADOLFO                  9
# 4  GONZALES_FERNANDEZ_MARIA ANTONIETA                  9
# 5   ESPINOZA_TIMOTEO_GLORIA ESTEFANIA                  9
#
#                        vc_cargo               vc_dependencia  \
# 1                 CA1-Asistente    DIRECCIÓN DE PRESTACIONES
# 2                  CA2-Analista      DIRECCIÓN DE PRODUCCIÓN
# 3  CA3-Especialista/Coordinador  OFICINA DE RECURSOS HUMANOS
# 4   CO2-Servidor de Act. Compl.                 JEFATURA ONP
# 5                 CA1-Asistente    DIRECCIÓN DE PRESTACIONES
#
#    mo_remuneraciones  mo_honorarios  mo_incentivo  mo_gratificacion  \
# 1                0.0        2006.49           0.0            668.83
# 2                0.0        5645.06           0.0           5645.06
# ...

# %%
df.nombre.value_counts()
# Out:
# MAMANI_QUILLA_EDY WILSON            4
# QUINTANA_MORALES_STHEFANY FARIDE    4
# TAIPE_CORREA_ELIZABETH              4
# AGUIRRE_ABENSUR_MARTHA YNES         4
# CAMUS_ALBA_DIANA ELIZABETH          4
#                                    ..
# ROMERO_SENCO_MAGALLY NORMA          1
# ROMERO_MARTINEZ_FELICITA ELENA      1
# ROJAS_LUCANO_WILMER ANGEL           1
# ROJAS_CALIXTRO_VICTOR VICENTE       1
# VILCHEZ_ARROYO_ROSA MARLENI         1
# Name: nombre, Length: 906, dtype: int64

# %%
# %%time
df[df.nombre == 'MAMANI_QUILLA_EDY WILSON']
# Out:
# CPU times: user 2.46 ms, sys: 0 ns, total: 2.46 ms
# Wall time: 2.47 ms
#                        nombre vc_regimen_laboral       vc_cargo  \
# 1    MAMANI_QUILLA_EDY WILSON                  9  CA1-Asistente
# 37   MAMANI_QUILLA_EDY WILSON                  9  CA1-Asistente
# 265  MAMANI_QUILLA_EDY WILSON                  9  CA1-Asistente
# 564  MAMANI_QUILLA_EDY WILSON                  9  CA1-Asistente
#
#                 vc_dependencia  mo_remuneraciones  mo_honorarios  \
# 1    DIRECCIÓN DE PRESTACIONES                0.0        2006.49
# 37   DIRECCIÓN DE PRESTACIONES                0.0        2006.49
# 265  DIRECCIÓN DE PRESTACIONES                0.0        2006.49
# 564  DIRECCIÓN DE PRESTACIONES                0.0        2006.49
#
#      mo_incentivo  mo_gratificacion  mo_otros_beneficios  mo_total  \
# 1             0.0            668.83                  0.0   2675.32
# 37            0.0            668.83                  0.0   2675.32
# ...

# %%
#encriptar
import hashlib
def encrypt_string(hash_string):
    sha_signature = \
        hashlib.sha256(hash_string.encode()).hexdigest()
    return sha_signature



x =  'MAMANI_QUILLA_EDY WILSON'
#df.keyvalue = df.keyvalue.astype(str).apply(lambda x: encrypt_string(x + 'v*+)y7%k^^-ch-0d7mh@wjl!i6yby8=rl2jmxmq%ct-xwv7@ox') )
#df.keyvalue = indha.str.upper()
llave = 'clase_ucsp'
print(encrypt_string(x + llave).upper())


encrypt_string('2' + llave).upper()
# Out:
# 1AC1D09A9B7CAF86F995FC45DDF79758CE9FFDBBAF0FE008ED230874C18750BC
# '7322001F6CF46CF4F2785BD4DBFE36918536E08CB20132B9D6BF2A3EF0052BC6'

# %%
#df.pk_id_personal.astype(str).apply(lambda x: encrypt_string(x + llave ).upper() )
df.nombre = df.nombre.astype(str).apply(lambda x: encrypt_string(x + llave ).upper() )
df.head(10)
# Out:
#                                                nombre vc_regimen_laboral  \
# 1   1AC1D09A9B7CAF86F995FC45DDF79758CE9FFDBBAF0FE0...                  9
# 2   E35EE21B7D135C40C48BE56C0296B6EAFC7539D97BAFEA...                  9
# 3   8A287DB1196C78A1B2F2B0A01178ED73A8A684C771170A...                  9
# 4   429477EA66DF5F8D50C84A0091D677CF8DAC05856823CF...                  9
# 5   70482BE0C993B24DEE018264ED6A807F96FA006A296E31...                  9
# 6   BE4FFFC04AA3350E10E5B4AF3CAC589020EDCCA70B9853...                  9
# 7   F1DADE0BBC694ADC0951C4D97AE329C8E3731D94C6EC7F...                  9
# 8   4259F078E92922C90D9A11CE44A3C423B9BF11AD4DA59E...                  9
# 9   70F16AF0861A7A976591225710DC22BAECFA320285FCB6...                  9
# 10  FDB9EC557D7D6A357C84F85F3C68EA0B58D83076D12AFE...                  9
#
#                         vc_cargo               vc_dependencia  \
# 1                  CA1-Asistente    DIRECCIÓN DE PRESTACIONES
# ...

# %%
for c in df.columns[1:]:
    print('*'*20, c, '*'*20)
    print(c, df[c].nunique())
# Out:
# ******************** vc_regimen_laboral ********************
# vc_regimen_laboral 3
# ******************** vc_cargo ********************
# vc_cargo 33
# ******************** vc_dependencia ********************
# vc_dependencia 22
# ******************** mo_remuneraciones ********************
# mo_remuneraciones 48
# ******************** mo_honorarios ********************
# mo_honorarios 71
# ******************** mo_incentivo ********************
# mo_incentivo 1
# ******************** mo_gratificacion ********************
# mo_gratificacion 114
# ******************** mo_otros_beneficios ********************
# mo_otros_beneficios 53
# ******************** mo_total ********************
# mo_total 175
# ******************** vc_obervaciones ********************
# vc_obervaciones 0
# ******************** codmes ********************
# codmes 1
